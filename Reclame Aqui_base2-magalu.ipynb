# %%
import selenium
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
import pandas as pd
from datetime import date
from selenium.webdriver.common.by import By
import csv
import time
import xlsxwriter 
options = webdriver.FirefoxOptions()
#options.add_argument('--headless')
navegador = webdriver.Firefox(options=options)
hoje = str(date.today())
import pandas as pd

#INPUT XLSX DATASET FROM PART AFILE PATH
###df = pd.read_excel(r'#XSLX FILE WITH PART A.xlsx', sheet_name = 'Ultragas3')
links = df['Link']

#INPUT THE .xlsx PATH THAT WILL BE THE FINAL DATASET
##workbook = xlsxwriter.Workbook(r'##magalu.xlsx') 
worksheet = workbook.add_worksheet(name='magalu')
i=1
try:
    for link in (links):
       
       navegador.get(link)
       title = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[1]/div[3]/h1').text).replace('\n','')
       description = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[1]/div[3]/p').text).replace('\n','')
       location= str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[1]/div[3]/div[1]/div[2]/div[1]/span').text).replace('\n','')
       submission_date = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[1]/div[3]/div[1]/div[2]/div[2]/span').text).replace('\n','')
       try:
           tag1 = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[1]/div[3]/div[1]/div[3]/ul/li[1]/div').text).replace('\n','')
       except:
           tag1 = ""
       try:
           tag2 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[1]/div[3]/div[1]/div[3]/ul/li[2]/div').text.replace('\n','')
       except:
        tag2 = ""
       try:
        tag3 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[1]/div[3]/div[1]/div[3]/ul/li[3]/div').text.replace('\n','')
       except:
        tag3 = ""
       try:
        tag4 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[1]/div[3]/div[1]/div[3]/ul/li[4]/div').text.replace('\n','')
       except:
        tag4 = ""
       try:
        tag5 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[1]/div[3]/div[1]/div[3]/ul/li[5]/div').text.replace('\n','')
       except:
        tag5 = ""
       try:
        tag6 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[1]/div[3]/div[1]/div[3]/ul/li[6]/div').text.replace('\n','')
       except:
        tag6 = ""
       try:
        tag7 = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[1]/div[3]/div[1]/div[3]/ul/li[7]/div').text).replace('\n','')
       except:
        tag7 = ""
       try:
        tag8 = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[1]/div[3]/div[1]/div[3]/ul/li[8]/div').text).replace('\n','')
       except:
        tag8 = ""
       try:
        tag9 = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[1]/div[3]/div[1]/div[3]/ul/li[9]/div').text).replace('\n','')
       except:
        tag9 = ""
       try:
        resposta_empresa = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[2]/div[1]/p').text).replace('\n','')
       except:
        resposta_empresa = str('Sem resposta da empresa')

       try:
        data_hora_resposta_empresa = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[2]/div[1]/div/span').text).replace('\n','')

       except:
        data_hora_resposta_empresa = str('Sem resposta da empresa')
       try:
        consideracao_consumidor = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[2]/div[2]/div[1]/p').text).replace('\n','')
       except:
        consideracao_consumidor = str("Sem Avaliação")
       try:    
        data_hora_consideracao_consumidor = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[2]/div[2]/div[1]/div/span').text).replace('\n','')
       except:
        data_hora_consideracao_consumidor = str("Sem Avaliação")
       try:
        Nota_atendimento = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[2]/div[4]/div[2]/div[3]/div/div').text)
       except:
        Nota_atendimento=0
       if Nota_atendimento==0:
        try:
            Nota_atendimento = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[2]/div[2]/div[2]/div[3]/div/div').text)
        except: 
            Nota_atendimento = str('0')
            pass
       try:
        problema_resolvido = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[2]/div[2]/div[2]/div[1]/div/div/span').text)
       except:
        problema_resolvido=0
       if problema_resolvido==0:
        try:
            problema_resolvido = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[2]/div[4]/div[2]/div[1]/div/div/span').text)
        except: 
            problema_resolvido=0
        try:
            problema_resolvido = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[2]/div[2]/div[2]/div[1]/div/div').text)
        except:
            problema_resolvido=str('Não respondido')     
         
       try:
        volta_negocio = str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[2]/div[2]/div[2]/div[2]/div/div').text)
       except:
        volta_negocio=0
       if volta_negocio==0:
        try:
            volta_negocio =str(navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/div/div[2]/div[1]/div[2]/div[4]/div[2]/div[2]/div/div').text)
        except: 
            volta_negocio = str('Não respondido')
            pass
           
      
      
       worksheet.write('A'+str(i), hoje)
       worksheet.write('B'+str(i), title )
       worksheet.write('C'+str(i), location)
       worksheet.write('D'+str(i), submission_date)
       worksheet.write('E'+str(i), tag1)
       worksheet.write('F'+str(i), tag2)
       worksheet.write('G'+str(i), tag3)
       worksheet.write('H'+str(i), tag4)
       worksheet.write('I'+str(i), tag5)
       worksheet.write('J'+str(i), tag6)
       worksheet.write('K'+str(i), tag7)
       worksheet.write('L'+str(i), tag8)
       worksheet.write('M'+str(i), description)
       worksheet.write('N'+str(i), resposta_empresa)
       worksheet.write('O'+str(i), data_hora_resposta_empresa)
       worksheet.write('P'+str(i), consideracao_consumidor)
       worksheet.write('Q'+str(i), data_hora_consideracao_consumidor)
       worksheet.write('R'+str(i), problema_resolvido)
       worksheet.write('S'+str(i), volta_negocio)
       worksheet.write('T'+str(i), Nota_atendimento)
       worksheet.write('U'+str(i), link)

       print('Página Capturada:    '+str(i)+'   -   '+str(link))
       i=i+1
       time.sleep(0.4)
except:
  workbook.close()
