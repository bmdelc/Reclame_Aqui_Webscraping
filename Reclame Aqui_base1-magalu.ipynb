# %%
import selenium
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
import pandas as pd
from datetime import date
from selenium.webdriver.common.by import By
import csv
import time
options = webdriver.FirefoxOptions()
#options.add_argument('--headless')
navegador = webdriver.Firefox(options=options)
hoje = str(date.today())



    
    
i=1
for i in range(1,26):
    
    navegador.get('https://www.reclameaqui.com.br/empresa/magazine-luiza-loja-online/lista-reclamacoes/?pagina='+str(i))
    try:
        navegador.find_element(By.XPATH,'/html/body/div[2]/div[2]/a[1]').click()
    except:
        exit()
    titulo1 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[1]/a/h4')
    titulo2 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[2]/a/h4')
    titulo3 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[3]/a/h4')
    titulo4 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[4]/a/h4')
    titulo5 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[5]/a/h4')
    titulo6 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[6]/a/h4')
    titulo7 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[7]/a/h4')
    titulo8 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[8]/a/h4')
    titulo9 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[9]/a/h4')
    titulo10 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[   ]/a/h4')
    
    desc1 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[1]/p')
    desc2 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[2]/p')
    desc3 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[3]/p')
    desc4 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[4]/p')
    desc5 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[5]/p')
    desc6 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[6]/p')
    desc7 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[7]/p')
    desc8 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[8]/p')
    desc9 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[9]/p')
    desc10 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[10]/p')
    
    resposta1 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[1]/div/span[1]')
    resposta2 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[2]/div/span[1]')
    resposta3 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[3]/div/span[1]')
    resposta4 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[4]/div/span[1]')
    resposta5 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[5]/div/span[1]')
    resposta6 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[6]/div/span[1]')
    resposta7 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[7]/div/span[1]')
    resposta8 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[8]/div/span[1]')
    resposta9 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[9]/div/span[1]')
    resposta10 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[10]/div/span[1]')
    
    link1 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[1]/a')
    link2 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[2]/a')
    link3 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[3]/a')
    link4 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[4]/a')
    link5 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[5]/a')
    link6 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[6]/a')
    link7 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[7]/a')
    link8 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[8]/a')
    link9 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[9]/a')
    link10 = navegador.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[1]/div[3]/main/section[2]/div[2]/div[2]/div[10]/a')
    
    
    ##INPUT relative path where to save the csv file
    ##with open(r'##magalu-avaliadas.csv##', 'a',newline='',encoding='UTF-8') as w:
        linha1 = '\n'+hoje+';'+str(titulo1.text)+';'+str(desc1.text)+';'+str(resposta1.text)+';'+str(link1.get_attribute('href'))+'\n'
        w.write(linha1)
        linha2 = hoje+';'+str(titulo2.text)+';'+str(desc2.text)+';'+str(resposta2.text)+';'+str(link2.get_attribute('href'))+'\n'
        w.write(linha2)
        linha3 = hoje+';'+str(titulo3.text)+';'+str(desc3.text)+';'+str(resposta3.text)+';'+str(link3.get_attribute('href'))+'\n'
        w.write(linha3)
        linha4 = hoje+';'+str(titulo4.text)+';'+str(desc4.text)+';'+str(resposta4.text)+';'+str(link4.get_attribute('href'))+'\n'
        w.write(linha4)
        linha5 = hoje+';'+str(titulo5.text)+';'+str(desc5.text)+';'+str(resposta5.text)+';'+str(link5.get_attribute('href'))+'\n'
        w.write(linha5)
        linha6 = hoje+';'+str(titulo6.text)+';'+str(desc6.text)+';'+str(resposta6.text)+';'+str(link6.get_attribute('href'))+'\n'
        w.write(linha6)
        linha7 = hoje+';'+str(titulo7.text)+';'+str(desc7.text)+';'+str(resposta7.text)+';'+str(link7.get_attribute('href'))+'\n'
        w.write(linha7)
        linha8 = hoje+';'+str(titulo8.text)+';'+str(desc8.text)+';'+str(resposta8.text)+';'+str(link8.get_attribute('href'))+'\n'
        w.write(linha8)
        linha9 = hoje+';'+str(titulo9.text)+';'+str(desc9.text)+';'+str(resposta9.text)+';'+str(link9.get_attribute('href'))+'\n'
        w.write(linha9)
        linha10 = hoje+';'+str(titulo10.text)+';'+str(desc10.text)+';'+str(resposta10.text)+';'+str(link10.get_attribute('href'))+'\n'
        w.write(linha10)
        print('Página Capturada:'+str(i))
    i=i+1
    time.sleep(3)
